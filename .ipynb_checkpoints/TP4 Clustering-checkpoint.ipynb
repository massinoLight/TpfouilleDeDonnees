# %% [markdown]
# # 1

# %%
from matplotlib import pyplot
from sklearn import *
import numpy
X1,Y1=datasets.make_blobs(n_samples=300, n_features=2, centers=4)

pyplot.figure(figsize = (10, 10))
pyplot.title("Clustering de valeurs générées aléatoirement ")

pyplot.xlabel("laxe des X")
pyplot.ylabel("laxe des Y")
x1 = []; y1 = []
x2 = []; y2 = []
x3 = []; y3 = []
x4 = []; y4 = []
for i in range(0,len(X1)):
    if Y1[i] == 0:
        x1.append(X1[i][0])
        y1.append(X1[i][1])
    else:
        if Y1[i] == 1:
            x2.append(X1[i][0])
            y2.append(X1[i][1])
        else:
            if Y1[i] == 2:
                x3.append(X1[i][0])
                y3.append(X1[i][1])
            else:
                x4.append(X1[i][0])
                y4.append(X1[i][1])






pyplot.scatter(x1, y1, c = 'red')
pyplot.scatter(x2, y2, c = 'yellow')
pyplot.scatter(x3, y3, c = 'blue')
pyplot.scatter(x4, y4, c = 'green')

pyplot.show()

# %% [markdown]
# # 2 Kmeans

# %%
from sklearn.cluster import KMeans
from matplotlib import pyplot

import numpy

kmeans = KMeans(n_clusters=4).fit(X1)
#print(len(kmeans.labels_))


pyplot.figure(figsize = (10, 10))
pyplot.title("Clustering avec kmeans ")

pyplot.xlabel("laxe des X")
pyplot.ylabel("laxe des Y")
x1 = []; y1 = []
x2 = []; y2 = []
x3 = []; y3 = []
x4 = []; y4 = []
for i in range(0,len(X1)):
    if kmeans.labels_[i] == 0:
        x1.append(X1[i][0])
        y1.append(X1[i][1])
    else:
        if kmeans.labels_[i] == 1:
            x2.append(X1[i][0])
            y2.append(X1[i][1])
        else:
            if kmeans.labels_[i] == 2:
                x3.append(X1[i][0])
                y3.append(X1[i][1])
            else:
                x4.append(X1[i][0])
                y4.append(X1[i][1])






pyplot.scatter(x1, y1, c = 'red')
pyplot.scatter(x2, y2, c = 'yellow')
pyplot.scatter(x3, y3, c = 'blue')
pyplot.scatter(x4, y4, c = 'green')

pyplot.show()

# %%
from sklearn.cluster import AgglomerativeClustering
from matplotlib import pyplot
import numpy
clustering = AgglomerativeClustering(n_clusters=4).fit(X1)


pyplot.figure(figsize = (10, 10))
pyplot.title("Hierarchical clustering")

pyplot.xlabel("laxe des X")
pyplot.ylabel("laxe des Y")
x1 = []; y1 = []
x2 = []; y2 = []
x3 = []; y3 = []
x4 = []; y4 = []
for i in range(0,len(X1)):
    if clustering.labels_[i] == 0:
        x1.append(X1[i][0])
        y1.append(X1[i][1])
    else:
        if clustering.labels_[i] == 1:
            x2.append(X1[i][0])
            y2.append(X1[i][1])
        else:
            if clustering.labels_[i] == 2:
                x3.append(X1[i][0])
                y3.append(X1[i][1])
            else:
                x4.append(X1[i][0])
                y4.append(X1[i][1])






pyplot.scatter(x1, y1, c = 'red')
pyplot.scatter(x2, y2, c = 'yellow')
pyplot.scatter(x3, y3, c = 'blue')
pyplot.scatter(x4, y4, c = 'green')

pyplot.show()

# %% [markdown]
# # 4  evaluate clustering results with 2 3 and 4 clusters

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

print(__doc__)

# Generating the sample data from make_blobs
# This particular setting has one distinct cluster and 3 clusters placed close
# together.
X, y =datasets.make_blobs(n_samples=300, n_features=2, centers=4)

range_n_clusters = [2, 3, 4]

for n_clusters in range_n_clusters:
    
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)
    ax1.set_xlim([-0.1, 1])
    
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# For n_clusters = 2 The average silhouette_score is : 0.5671050746511321
# For n_clusters = 3 The average silhouette_score is : 0.6774690788954725
# For n_clusters = 4 The average silhouette_score is : 0.7163284757660432

# %% [markdown]
# # 5 Kmeans and hierarchical clustering on iris data

# %%
from sklearn import *
from sklearn.cluster import KMeans
from matplotlib import pyplot
import numpy

print("# 1 - Chargez les données  Iris:")
irisData,irisTarget = datasets.load_iris(return_X_y=True)





kmeans = KMeans(n_clusters=3).fit(irisData)



pyplot.figure(figsize = (10, 10))
pyplot.title("Clustering iris data with kmeans ")

pyplot.xlabel("laxe des X")
pyplot.ylabel("laxe des Y")
x1 = []; y1 = []
x2 = []; y2 = []
x3 = []; y3 = []

for i in range(0,len(X1)):
    if kmeans.labels_[i] == 0:
        x1.append(X1[i][0])
        y1.append(X1[i][1])
    else:
        if kmeans.labels_[i] == 1:
            x2.append(X1[i][0])
            y2.append(X1[i][1])
        else:
            if kmeans.labels_[i] == 2:
                x3.append(X1[i][0])
                y3.append(X1[i][1])
            






pyplot.scatter(x1, y1, c = 'red')
pyplot.scatter(x2, y2, c = 'yellow')
pyplot.scatter(x3, y3, c = 'blue')


pyplot.show()
# Out:
# # 1 - Chargez les données  Iris:

# %%
from sklearn import *
from sklearn.cluster import KMeans
from matplotlib import pyplot
import numpy

print("# 1 - Chargez les données  Iris:")
irisData,irisTarget = datasets.load_iris(return_X_y=True)




clustering = AgglomerativeClustering(n_clusters=3).fit(irisData)


pyplot.figure(figsize = (10, 10))
pyplot.title("Hierarchical clustering on iris data")

pyplot.xlabel("laxe des X")
pyplot.ylabel("laxe des Y")
x1 = []; y1 = []
x2 = []; y2 = []
x3 = []; y3 = []

for i in range(0,len(X1)):
    if clustering.labels_[i] == 0:
        x1.append(X1[i][0])
        y1.append(X1[i][1])
    else:
        if clustering.labels_[i] == 1:
            x2.append(X1[i][0])
            y2.append(X1[i][1])
        else:
            if clustering.labels_[i] == 2:
                x3.append(X1[i][0])
                y3.append(X1[i][1])
            






pyplot.scatter(x1, y1, c = 'red')
pyplot.scatter(x2, y2, c = 'yellow')
pyplot.scatter(x3, y3, c = 'blue')


pyplot.show()
# Out:
# # 1 - Chargez les données  Iris:

# %% [markdown]
# # Silhouette index for k-means

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

clusterer = KMeans(n_clusters=3, random_state=10)
cluster_labels = clusterer.fit_predict(irisData)

silhouette_avg = silhouette_score(irisData, irisTarget)
print("For n_clusters =", 3,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
sample_silhouette_values = silhouette_samples(irisData, cluster_labels)
# Out:
# For n_clusters = 3 The average silhouette_score is : 0.5034774406932957

# %% [markdown]
# # Silhouette index for hierarchical clustering

# %%
clusterer = AgglomerativeClustering(n_clusters=3)
cluster_labels = clusterer.fit_predict(irisData)

silhouette_avg = silhouette_score(irisData, irisTarget)
print("For n_clusters =", 3,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
sample_silhouette_values = silhouette_samples(irisData, cluster_labels)
# Out:
# For n_clusters = 3 The average silhouette_score is : 0.5034774406932957

# %% [markdown]
# # we notice that the results are identical for the two algorithms
